# %%
#help!
#https://stackoverflow.com/questions/38943339/python-rest-api-looping-through-dictionary-object
#https://rickandmortyapi.com/api/character
#https://rickandmortyapi.com/documentation

# %%
import requests as r
response = r.get('https://rickandmortyapi.com/api/character')
print(response.status_code)
if response.status_code == 200:
    data = response.json()
print(data)
# print(data['results'])
# #going to get the name
# print(data['results'][0]['name'])
# #going to get an image of the person whose name we got
#print(data['results'][0]['image'])
# Out:
# 200
# ...

# %%
print(data['results'])
# Out:
# [{'id': 1, 'name': 'Rick Sanchez', 'status': 'Alive', 'species': 'Human', 'type': '', 'gender': 'Male', 'origin': {'name': 'Earth (C-137)', 'url': 'https://rickandmortyapi.com/api/location/1'}, 'location': {'name': 'Citadel of Ricks', 'url': 'https://rickandmortyapi.com/api/location/3'}, 'image': 'https://rickandmortyapi.com/api/character/avatar/1.jpeg', 'episode': ['https://rickandmortyapi.com/api/episode/1', 'https://rickandmortyapi.com/api/episode/2', 'https://rickandmortyapi.com/api/episode/3', 'https://rickandmortyapi.com/api/episode/4', 'https://rickandmortyapi.com/api/episode/5', 'https://rickandmortyapi.com/api/episode/6', 'https://rickandmortyapi.com/api/episode/7', 'https://rickandmortyapi.com/api/episode/8', 'https://rickandmortyapi.com/api/episode/9', 'https://rickandmortyapi.com/api/episode/10', 'https://rickandmortyapi.com/api/episode/11', 'https://rickandmortyapi.com/api/episode/12', 'https://rickandmortyapi.com/api/episode/13', 'https://rickandmortyapi.com/api/episode
# ...

# %%
print(data['results'][0])
# Out:
# {'id': 1, 'name': 'Rick Sanchez', 'status': 'Alive', 'species': 'Human', 'type': '', 'gender': 'Male', 'origin': {'name': 'Earth (C-137)', 'url': 'https://rickandmortyapi.com/api/location/1'}, 'location': {'name': 'Citadel of Ricks', 'url': 'https://rickandmortyapi.com/api/location/3'}, 'image': 'https://rickandmortyapi.com/api/character/avatar/1.jpeg', 'episode': ['https://rickandmortyapi.com/api/episode/1', 'https://rickandmortyapi.com/api/episode/2', 'https://rickandmortyapi.com/api/episode/3', 'https://rickandmortyapi.com/api/episode/4', 'https://rickandmortyapi.com/api/episode/5', 'https://rickandmortyapi.com/api/episode/6', 'https://rickandmortyapi.com/api/episode/7', 'https://rickandmortyapi.com/api/episode/8', 'https://rickandmortyapi.com/api/episode/9', 'https://rickandmortyapi.com/api/episode/10', 'https://rickandmortyapi.com/api/episode/11', 'https://rickandmortyapi.com/api/episode/12', 'https://rickandmortyapi.com/api/episode/13', 'https://rickandmortyapi.com/api/episode/
# ...

# %%
print(data['results'][0]['name'])
# Out:
# Rick Sanchez

# %%
print(data['results'][0]['image'])
# Out:
# https://rickandmortyapi.com/api/character/avatar/1.jpeg

# %%
print(data['results'])
# Out:
# [{'id': 1, 'name': 'Rick Sanchez', 'status': 'Alive', 'species': 'Human', 'type': '', 'gender': 'Male', 'origin': {'name': 'Earth (C-137)', 'url': 'https://rickandmortyapi.com/api/location/1'}, 'location': {'name': 'Citadel of Ricks', 'url': 'https://rickandmortyapi.com/api/location/3'}, 'image': 'https://rickandmortyapi.com/api/character/avatar/1.jpeg', 'episode': ['https://rickandmortyapi.com/api/episode/1', 'https://rickandmortyapi.com/api/episode/2', 'https://rickandmortyapi.com/api/episode/3', 'https://rickandmortyapi.com/api/episode/4', 'https://rickandmortyapi.com/api/episode/5', 'https://rickandmortyapi.com/api/episode/6', 'https://rickandmortyapi.com/api/episode/7', 'https://rickandmortyapi.com/api/episode/8', 'https://rickandmortyapi.com/api/episode/9', 'https://rickandmortyapi.com/api/episode/10', 'https://rickandmortyapi.com/api/episode/11', 'https://rickandmortyapi.com/api/episode/12', 'https://rickandmortyapi.com/api/episode/13', 'https://rickandmortyapi.com/api/episode
# ...

# %%
print(data['results'][1])
# Out:
# {'id': 2, 'name': 'Morty Smith', 'status': 'Alive', 'species': 'Human', 'type': '', 'gender': 'Male', 'origin': {'name': 'unknown', 'url': ''}, 'location': {'name': 'Citadel of Ricks', 'url': 'https://rickandmortyapi.com/api/location/3'}, 'image': 'https://rickandmortyapi.com/api/character/avatar/2.jpeg', 'episode': ['https://rickandmortyapi.com/api/episode/1', 'https://rickandmortyapi.com/api/episode/2', 'https://rickandmortyapi.com/api/episode/3', 'https://rickandmortyapi.com/api/episode/4', 'https://rickandmortyapi.com/api/episode/5', 'https://rickandmortyapi.com/api/episode/6', 'https://rickandmortyapi.com/api/episode/7', 'https://rickandmortyapi.com/api/episode/8', 'https://rickandmortyapi.com/api/episode/9', 'https://rickandmortyapi.com/api/episode/10', 'https://rickandmortyapi.com/api/episode/11', 'https://rickandmortyapi.com/api/episode/12', 'https://rickandmortyapi.com/api/episode/13', 'https://rickandmortyapi.com/api/episode/14', 'https://rickandmortyapi.com/api/episode/15'
# ...

# %%
print(data['results'][1]['name'])
# Out:
# Morty Smith

# %%
#going to get the name
print(data['results'][0]['name'])

#going to get an image of the person whose name we got
print(data['results'][0]['image'])

#create a function
#make the apit call and return a dictionary of character names: image urls

def getCharacterImages():
    response = r.get('https://rickandmortyapi.com/api/character')
    if response.status_code == 200:
        data = response.json()
    else: #the api was down or we had a bad request
        return response.status_code #return that status code
    print(data)
    #start producing our dictionary character_name: <img url>
    characters = {}
   
getCharacterImages()
# Out:
# Rick Sanchez
# https://rickandmortyapi.com/api/character/avatar/1.jpeg
# ...

# %%
def getCharacterImages():
    response = r.get('https://rickandmortyapi.com/api/character')
    if response.status_code == 200:
        data = response.json()
    else: #the api was down or we had a bad request
        return response.status_code #return that status code
    print(data)
    #start producing our dictionary character_name: <img url>
    characters = {}
   
getCharacterImages()
#testing the function call
# Out:
# {'info': {'count': 826, 'pages': 42, 'next': 'https://rickandmortyapi.com/api/character?page=2', 'prev': None}, 'results': [{'id': 1, 'name': 'Rick Sanchez', 'status': 'Alive', 'species': 'Human', 'type': '', 'gender': 'Male', 'origin': {'name': 'Earth (C-137)', 'url': 'https://rickandmortyapi.com/api/location/1'}, 'location': {'name': 'Citadel of Ricks', 'url': 'https://rickandmortyapi.com/api/location/3'}, 'image': 'https://rickandmortyapi.com/api/character/avatar/1.jpeg', 'episode': ['https://rickandmortyapi.com/api/episode/1', 'https://rickandmortyapi.com/api/episode/2', 'https://rickandmortyapi.com/api/episode/3', 'https://rickandmortyapi.com/api/episode/4', 'https://rickandmortyapi.com/api/episode/5', 'https://rickandmortyapi.com/api/episode/6', 'https://rickandmortyapi.com/api/episode/7', 'https://rickandmortyapi.com/api/episode/8', 'https://rickandmortyapi.com/api/episode/9', 'https://rickandmortyapi.com/api/episode/10', 'https://rickandmortyapi.com/api/episode/11', 'https://
# ...

# %%
#now loop through this information

def getCharacterImages():
    response = r.get('https://rickandmortyapi.com/api/character')
    if response.status_code == 200:
        data = response.json()
    else: #the api was down or we had a bad request
        return response.status_code #return that status code
    #start producing our dictionary character_name: <img url>
    characters = {}
    for data in data['results']:
        if data['image']:#make sure we dont get that character if they dont have an image
        #print(data['name'],data['image'], '\n')
            characters[data['name']] = data['image']
    #print(characters) to see if the dictionary is what you want
        #print(characters[data['name']])
        #print(data['image'])
        print(data['name'])
       
    return characters
   
getCharacterImages()

#trying to loop through the dictionary
#print(data['results'][0]['name'], data['results'][0]['image'])
# Out:
# Rick Sanchez
# Morty Smith
# Summer Smith
# Beth Smith
# Jerry Smith
# Abadango Cluster Princess
# Abradolf Lincler
# Adjudicator Rick
# Agency Director
# Alan Rails
# Albert Einstein
# Alexander
# Alien Googah
# Alien Morty
# Alien Rick
# Amish Cyborg
# Annie
# Antenna Morty
# Antenna Rick
# Ants in my Eyes Johnson
# {'Rick Sanchez': 'https://rickandmortyapi.com/api/character/avatar/1.jpeg',
#  'Morty Smith': 'https://rickandmortyapi.com/api/character/avatar/2.jpeg',
#  'Summer Smith': 'https://rickandmortyapi.com/api/character/avatar/3.jpeg',
#  'Beth Smith': 'https://rickandmortyapi.com/api/character/avatar/4.jpeg',
#  'Jerry Smith': 'https://rickandmortyapi.com/api/character/avatar/5.jpeg',
#  'Abadango Cluster Princess': 'https://rickandmortyapi.com/api/character/avatar/6.jpeg',
#  'Abradolf Lincler': 'https://rickandmortyapi.com/api/character/avatar/7.jpeg',
#  'Adjudicator Rick': 'https://rickandmortyapi.com/api/character/avatar/8.jpeg',
# ...

# %%
def getCharacterImages():
    response = r.get('https://rickandmortyapi.com/api/character')
    if response.status_code == 200:
        data = response.json()
    else: 
        return response.status_code 
    characters = []
    for data in data['results']:
        if data['image']:
            characters.append((data['name'], data['image']))
            #print(data['name'], data['image'])
    
    return characters
   
getCharacterImages()
# Out:
# [('Rick Sanchez', 'https://rickandmortyapi.com/api/character/avatar/1.jpeg'),
#  ('Morty Smith', 'https://rickandmortyapi.com/api/character/avatar/2.jpeg'),
#  ('Summer Smith', 'https://rickandmortyapi.com/api/character/avatar/3.jpeg'),
#  ('Beth Smith', 'https://rickandmortyapi.com/api/character/avatar/4.jpeg'),
#  ('Jerry Smith', 'https://rickandmortyapi.com/api/character/avatar/5.jpeg'),
#  ('Abadango Cluster Princess',
#   'https://rickandmortyapi.com/api/character/avatar/6.jpeg'),
#  ('Abradolf Lincler',
#   'https://rickandmortyapi.com/api/character/avatar/7.jpeg'),
#  ('Adjudicator Rick',
#   'https://rickandmortyapi.com/api/character/avatar/8.jpeg'),
#  ('Agency Director',
#   'https://rickandmortyapi.com/api/character/avatar/9.jpeg'),
#  ('Alan Rails', 'https://rickandmortyapi.com/api/character/avatar/10.jpeg'),
#  ('Albert Einstein',
#   'https://rickandmortyapi.com/api/character/avatar/11.jpeg'),
# ...

# %%
# print json_data['human']
# >> [
#       {
#         "h": 310,
#         "prob": 0.9588886499404907,
#         "w": 457,
#         "x": 487,
#         "y": 1053
#       },
#       {
#         "h": 283,
#         "prob": 0.8738606572151184,
#         "w": 455,
#         "x": 1078,
#         "y": 1074
#       },
#       .
#       .
#   ]


# for data in json_data['human']:
#     print data
# >> {
#      "h": 310,
#      "prob": 0.9588886499404907,
#      "w": 457,
#      "x": 487,
#      "y": 1053
#    } 

#    {
#      "h": 283,
#      "prob": 0.8738606572151184,
#      "w": 455,
#      "x": 1078,
#      "y": 1074
#     }
# .
# .


# for data in json_data['human']:
#     print data['h']
# >> 310
#    283

# %%
 print(data['results'][0]['image'])
# Out:
# https://rickandmortyapi.com/api/character/avatar/1.jpeg

# %%
print(data['results'][0]['name'], data['results'][0]['image'],data['results'][0] )
